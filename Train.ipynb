# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OrdinalEncoder
from numpy import asarray

# %%
df_tr = pd.read_csv('train.csv')
df_tr.head(65)
# Out:
#     row_id                 time  x  y direction  congestion
# 0        0  1991-04-01 00:00:00  0  0        EB          70
# 1        1  1991-04-01 00:00:00  0  0        NB          49
# 2        2  1991-04-01 00:00:00  0  0        SB          24
# 3        3  1991-04-01 00:00:00  0  1        EB          18
# 4        4  1991-04-01 00:00:00  0  1        NB          60
# ..     ...                  ... .. ..       ...         ...
# 60      60  1991-04-01 00:00:00  2  3        NB          64
# 61      61  1991-04-01 00:00:00  2  3        NE          30
# 62      62  1991-04-01 00:00:00  2  3        SB          70
# 63      63  1991-04-01 00:00:00  2  3        SW          29
# 64      64  1991-04-01 00:00:00  2  3        WB          26
#
# [65 rows x 6 columns]

# %%
route_train = df_tr['x'].astype(str) + df_tr['y'].astype(str) + df_tr['direction']
df_tr.insert(2, 'route', route_train )

# %%
df_tr = df_tr.drop(['time', 'x', 'y', 'direction', 'row_id'], axis = 1)

# %%
df_tr
# Out:
#        route  congestion
# 0       00EB          70
# 1       00NB          49
# 2       00SB          24
# 3       01EB          18
# 4       01NB          60
# ...      ...         ...
# 848830  23NB          54
# 848831  23NE          28
# 848832  23SB          68
# 848833  23SW          17
# 848834  23WB          24
#
# [848835 rows x 2 columns]

# %%
ct = asarray(df_tr['route'])
ct
# Out:
# (848835,)

# %%
type(df_tr['route'])
# Out:
# pandas.core.series.Series

# %%
oe = OrdinalEncoder()
df_tr['route'] = oe.fit_transform(ct.reshape(-1,1))

# %%
df_tr.tail()
# Out:
#         route  congestion
# 848830   60.0          54
# 848831   61.0          28
# 848832   62.0          68
# 848833   63.0          17
# 848834   64.0          24

# %%
def pairing(df_tr, seq_len=195):

    x = []
    y = []

    for i in range(0,(df_tr.shape[0] - seq_len+1), seq_len+1 ): # range is reduced by the len of seq + 1 so that we do not go out of bounds
                                                            # we step for that same amount of steps as the seq_len
        seq = np.zeros( (seq_len, df_tr.shape[1]) ) #creating a matrix of zeros with the shape of seq_len and the number of columns of the data
        
        for j in range(seq_len):  # filling the matrix with the data

            seq[j] = df_tr.values[i+j]  # filling the matrix with the data we add i to make the jump of the seq_len

        x.append(seq.flatten())  # flattening the matrix and appending it to the x list
        y.append( df_tr["congestion"][i+seq_len] )  # appending the target to the y list 

    return np.array(x), np.array(y)

#print(data.shape)

x, y = pairing(df_tr)

# %%
x.shape
# Out:
# (4330, 390)

# %%
np.savetxt('x.csv', x, delimiter=',')

# %%
np.savetxt('y.csv', y, delimiter=',')

# %%
y.shape
# Out:
# (4330,)

# %%
from sklearn.model_selection import TimeSeriesSplit
tscv = TimeSeriesSplit(test_size=2)
for train_index, test_index in tscv.split(x):
    x_train, x_test = x[train_index], x[test_index]
    y_train, y_test = y[train_index], y[test_index
#         -0.93424498, -0.79850534,  0.78670419, -0.74497326, -0.10333211,
#         -0.6914582 ,  1.41803155, -0.6379573 , -1.28258298, -0.58446772,
#         -0.94057828, -0.53098661, -0.63908528, -0.47751113,  0.02510771,
#         -0.42403844, -0.09934689, -0.37056567,  0.67503733, -0.31709   ,
#         -0.35783688, -0.26360856,  1.41248509, -0.21011852, -0.58320788,
#         -0.156617  ,  0.19528343, -0.10310116,  1.31340403, -0.04956813,
#          0.60018664,  0.00398496,  0.20446051,  0.05756099, -0.65134522,
#          0.11116284,  0.5472114 ,  0.1647934 ,  0.42153049,  0.21845558,
#          0.61339377,  0.27215229, -1.23203018,  0.32588645,  0.60783595,
#          0.37966099,  0.13518475,  0.43266616,  1.31404977,  0.48569348,
#         -0.46587913,  0.53873904,  1.48194805,  0.59179891,  1.01601571,
#          0.64486914, -1.42809062,  0.69794579, -1.57270069,  0.7510249 ,
#         -1.13846788,  0.80410252, -0.99864342,  0.85717467, -2.55877689,
#          0.91023741, -0.10623523,  0.96328675, -0.2349152 ,  1.01631875,
#          1.02364265,  1.06932942,  0.31000635,  1.12231483, -0.35807134,
#          1.175271  , -1.84101859,  1.22819401,  0.73485539,  1.2810799 ,
#         -1.59490129,  1.33392476,  0.06455386,  1.38672466,  1.20058318,
#          1.43947571, -0.17712463,  1.49217401,  0.25116455,  1.54481568,
#         -1.35001162,  1.59739688,  1.32128855,  1.64991376, -1.63873184,
#          1.7023625 , -0.04690786, -1.71309862, -0.46394115, -1.65968131,
#         -0.99983903, -1.60548414,  0.3117336 , -1.55135058, -1.52737268,
#         -1.49727763,  1.00417024, -1.44326232,  0.6046129 , -1.38930167,
#         -0.58171523, -1.33539273, -0.22449301, -1.28153255,  0.7237598 ,
#         -1.22771822,  0.82795835, -1.1739468 , -0.60407008, -1.12021538,
#         -1.72406656, -1.06652108, -0.93982864, -1.01286101, -1.59106592,
#         -0.95923226,  1.37787644, -0.90563198, -0.9365898 , -0.8520573 ,
#         -0.04598022, -0.79850534,  0.01055039, -0.74497326, -0.11129324,
#         -0.6914582 ,  0.34647524, -0.6379573 , -0.88561058, -0.58446772,
#         -2.15236849, -0.53098661, -0.35192232, -0.47751113,  0.24713505,
#         -0.42403844, -0.87225353, -0.37056567,  0.8547182 , -0.31709   ,
#          0.12971583, -0.26360856,  1.19679204, -0.21011852, -0.33761618,
#         -0.156617  ,  0.01094588, -0.10310116,  1.49772496, -0.04956813,
#          0.97161375,  0.00398496,  0.57017928,  0.05756099, -0.3434545 ,
#          0.11116284,  0.76776565,  0.1647934 , -0.10062933,  0.21845558,
#          0.31046658,  0.27215229, -0.87906483,  0.32588645, -0.69896962]])

# %%
from os import pardir
import pandas as pd
import numpy as np

from sklearn.tree          import DecisionTreeRegressor
from sklearn.ensemble      import RandomForestRegressor
from sklearn.ensemble      import ExtraTreesRegressor
from sklearn.ensemble      import AdaBoostRegressor
from sklearn.ensemble      import GradientBoostingRegressor
from xgboost               import XGBRegressor
from lightgbm              import LGBMRegressor
from catboost              import CatBoostRegressor
from sklearn.linear_model  import LinearRegression
from sklearn.svm           import SVR
from sklearn import metrics 
from sklearn.preprocessing import StandardScaler
import time

# %%
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
regressors = {
   "Decision Tree": DecisionTreeRegressor(),
   "Extra Trees":   ExtraTreesRegressor(n_estimators=100),
   "Random Forest": RandomForestRegressor(n_estimators=100),
   "AdaBoost":      AdaBoostRegressor(n_estimators=100),
   "Skl GBM":       GradientBoostingRegressor(n_estimators=100),
   "XGBoost":       XGBRegressor(n_estimators=100),
   "LightGBM":      LGBMRegressor(n_estimators=100),
   "CatBoost":      CatBoostRegressor(n_estimators=100),
  'Linear Regression' : LinearRegression(),
  'svr'              :  SVR()
}

# %%
results = pd.DataFrame({'Model': [], 'MSE': [], 'MAE': [], " % error": [], 'Time': []})
rang = abs(y_train.max()) - abs(y_train.min())
for model_name, model in regressors.items():
    
    start_time = time.time()
    model.fit(x_train, y_train)
    total_time = time.time() - start_time
        
    pred = model.predict(x_test)
    
    results = results.append({"Model":    model_name,
                              "MSE": metrics.mean_squared_error(y_test, pred),
                              "MAE": metrics.mean_absolute_error(y_test, pred),
                              " % error": metrics.mean_squared_error(y_test, pred) / rang,
                              "Time":     total_time},
                              ignore_index=True)
### END SOLUTION


results_ord = results.sort_values(by=['MSE'], ascending=True, ignore_index=True)
results_ord.index += 1 
results_ord.style.bar(subset=['MSE', 'MAE'], vmin=0, vmax=100, color='#5fba7d')
# Out:
# [16:35:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Learning rate set to 0.291514
# 0:	learn: 14.0792488	total: 106ms	remaining: 10.5s
# 1:	learn: 12.3331036	total: 139ms	remaining: 6.82s
# 2:	learn: 11.0776123	total: 189ms	remaining: 6.11s
# 3:	learn: 10.2111342	total: 223ms	remaining: 5.36s
# 4:	learn: 9.7624354	total: 266ms	remaining: 5.05s
# 5:	learn: 9.4464703	total: 307ms	remaining: 4.8s
# 6:	learn: 9.2837135	total: 349ms	remaining: 4.63s
# 7:	learn: 9.1337779	total: 394ms	remaining: 4.53s
# 8:	learn: 9.0432466	total: 455ms	remaining: 4.6s
# 9:	learn: 8.9561361	total: 501ms	remaining: 4.5s
# 10:	learn: 8.8869598	total: 540ms	remaining: 4.37s
# 11:	learn: 8.8467272	total: 593ms	remaining: 4.35s
# 12:	learn: 8.8036150	total: 637ms	remaining: 4.26s
# 13:	learn: 8.7550585	total: 678ms	remaining: 4.16s
# 14:	learn: 8.7052987	total: 719ms	remaining: 4.07s
# 15:	learn: 8.6571037	total: 758ms	remaining: 3.98s
# 16:	learn: 8.6235954	total: 798ms	remaining: 3.89s
# 17:	learn: 8.6016114	total: 833ms	remaining: 3.79s
# 18:	learn: 8.5881214	total: 904ms	remaining: 3.85s
# 19:	learn: 8.5525389	total: 944ms	remaining: 3.77s
# 20:	learn: 8.5276518	total: 990ms	remaining: 3.73s
# 21:	learn: 8.4907801	total: 1.04s	remaining: 3.68s
# 22:	learn: 8.4565223	total: 1.09s	remaining: 3.64s
# 23:	learn: 8.4320067	total: 1.13s	remaining: 3.59s
# 24:	learn: 8.4108157	total: 1.18s	remaining: 3.55s
# 25:	learn: 8.3861756	total: 1.24s	remaining: 3.54s
# 72:	learn: 6.8219848	total: 3.55s	remaining: 1.31s
# 73:	learn: 6.8059867	total: 3.58s	remaining: 1.26s
# 74:	learn: 6.7905332	total: 3.63s	remaining: 1.21s
# 75:	learn: 6.7367322	total: 3.67s	remaining: 1.16s
# 76:	learn: 6.7017788	total: 3.72s	remaining: 1.11s
# 77:	learn: 6.6804744	total: 3.77s	remaining: 1.06s
# 78:	learn: 6.6765265	total: 3.82s	remaining: 1.01s
# 79:	learn: 6.6576156	total: 3.85s	remaining: 963ms
# 80:	learn: 6.6314102	total: 3.9s	remaining: 915ms
# 81:	learn: 6.6066234	total: 3.95s	remaining: 867ms
# 82:	learn: 6.5816201	total: 4s	remaining: 820ms
# 83:	learn: 6.5476980	total: 4.04s	remaining: 769ms
# 84:	learn: 6.5134755	total: 4.08s	remaining: 721ms
# 85:	learn: 6.5099595	total: 4.13s	remaining: 672ms
# 86:	learn: 6.4835911	total: 4.17s	remaining: 623ms
# 87:	learn: 6.4607604	total: 4.2s	remaining: 573ms
# 88:	learn: 6.4276888	total: 4.24s	remaining: 524ms
# 89:	learn: 6.4064229	total: 4.29s	remaining: 477ms
# 90:	learn: 6.3845033	total: 4.35s	remaining: 431ms
# 91:	learn: 6.3351022	total: 4.41s	remaining: 384ms
# 92:	learn: 6.3044687	total: 4.45s	remaining: 335ms
# 93:	learn: 6.2770963	total: 4.51s	remaining: 288ms
# 94:	learn: 6.2504699	total: 4.56s	remaining: 240ms
# 95:	learn: 6.2220206	total: 4.62s	remaining: 192ms
# 96:	learn: 6.1917851	total: 4.66s	remaining: 144ms
# 97:	learn: 6.1859908	total: 4.71s	remaining: 96.1ms
# 98:	learn: 6.1612772	total: 4.74s	remaining: 47.9ms
# 99:	learn: 6.1541616	total: 4.78s	remaining: 0us
# <style type="text/css">
# #T_86bcc_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 9.7%, transparent 9.7%);
# }
# #T_86bcc_row0_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 2.8%, transparent 2.8%);
# }
# #T_86bcc_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 13.9%, transparent 13.9%);
# }
# #T_86bcc_row1_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 3.0%, transparent 3.0%);
# }
# #T_86bcc_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 14.7%, transparent 14.7%);
# }
# #T_86bcc_row2_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 3.4%, transparent 3.4%);
# }
# #T_86bcc_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 18.1%, transparent 18.1%);
# }
# #T_86bcc_row3_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 3.2%, transparent 3.2%);
# }
# #T_86bcc_row4_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 18.4%, transparent 18.4%);
# }
# #T_86bcc_row4_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 4.3%, transparent 4.3%);
# }
# #T_86bcc_row5_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 20.0%, transparent 20.0%);
# }
# #T_86bcc_row5_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 4.0%, transparent 4.0%);
# }
# #T_86bcc_row6_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 20.1%, transparent 20.1%);
# }
# #T_86bcc_row6_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 4.5%, transparent 4.5%);
# }
# #T_86bcc_row7_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 24.6%, transparent 24.6%);
# }
# #T_86bcc_row7_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 5.0%, transparent 5.0%);
# }
# #T_86bcc_row8_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 31.4%, transparent 31.4%);
# }
# #T_86bcc_row8_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 5.6%, transparent 5.6%);
# }
# #T_86bcc_row9_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 49.2%, transparent 49.2%);
# }
# #T_86bcc_row9_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 6.8%, transparent 6.8%);
# }
# </style>
# <table id="T_86bcc_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >MAE</th>
#       <th class="col_heading level0 col3" > % error</th>
#       <th class="col_heading level0 col4" >Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86bcc_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_86bcc_row0_col0" class="data row0 col0" >CatBoost</td>
#       <td id="T_86bcc_row0_col1" class="data row0 col1" >9.718874</td>
#       <td id="T_86bcc_row0_col2" class="data row0 col2" >2.824275</td>
#       <td id="T_86bcc_row0_col3" class="data row0 col3" >0.097189</td>
#       <td id="T_86bcc_row0_col4" class="data row0 col4" >6.502273</td>
#     </tr>
#     <tr>
#       <th id="T_86bcc_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_86bcc_row1_col0" class="data row1 col0" >LightGBM</td>
#       <td id="T_86bcc_row1_col1" class="data row1 col1" >13.917366</td>
#       <td id="T_86bcc_row1_col2" class="data row1 col2" >2.959090</td>
#       <td id="T_86bcc_row1_col3" class="data row1 col3" >0.139174</td>
#       <td id="T_86bcc_row1_col4" class="data row1 col4" >2.677725</td>
#     </tr>
#     <tr>
#       <th id="T_86bcc_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_86bcc_row2_col0" class="data row2 col0" >Random Forest</td>
#       <td id="T_86bcc_row2_col1" class="data row2 col1" >14.744650</td>
#       <td id="T_86bcc_row2_col2" class="data row2 col2" >3.405000</td>
#       <td id="T_86bcc_row2_col3" class="data row2 col3" >0.147447</td>
#       <td id="T_86bcc_row2_col4" class="data row2 col4" >132.116415</td>
#     </tr>
#     <tr>
#       <th id="T_86bcc_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_86bcc_row3_col0" class="data row3 col0" >Extra Trees</td>
#       <td id="T_86bcc_row3_col1" class="data row3 col1" >18.088200</td>
#       <td id="T_86bcc_row3_col2" class="data row3 col2" >3.210000</td>
#       <td id="T_86bcc_row3_col3" class="data row3 col3" >0.180882</td>
#       <td id="T_86bcc_row3_col4" class="data row3 col4" >74.567051</td>
#     </tr>
#     <tr>
#       <th id="T_86bcc_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_86bcc_row4_col0" class="data row4 col0" >XGBoost</td>
#       <td id="T_86bcc_row4_col1" class="data row4 col1" >18.415706</td>
#       <td id="T_86bcc_row4_col2" class="data row4 col2" >4.291113</td>
#       <td id="T_86bcc_row4_col3" class="data row4 col3" >0.184157</td>
#       <td id="T_86bcc_row4_col4" class="data row4 col4" >6.289174</td>
#     </tr>
#     <tr>
#       <th id="T_86bcc_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_86bcc_row5_col0" class="data row5 col0" >Decision Tree</td>
#       <td id="T_86bcc_row5_col1" class="data row5 col1" >20.000000</td>
#       <td id="T_86bcc_row5_col2" class="data row5 col2" >4.000000</td>
#       <td id="T_86bcc_row5_col3" class="data row5 col3" >0.200000</td>
#       <td id="T_86bcc_row5_col4" class="data row5 col4" >2.953194</td>
#     </tr>
#     <tr>
#       <th id="T_86bcc_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_86bcc_row6_col0" class="data row6 col0" >Linear Regression</td>
#       <td id="T_86bcc_row6_col1" class="data row6 col1" >20.082543</td>
#       <td id="T_86bcc_row6_col2" class="data row6 col2" >4.458526</td>
#       <td id="T_86bcc_row6_col3" class="data row6 col3" >0.200825</td>
#       <td id="T_86bcc_row6_col4" class="data row6 col4" >0.483031</td>
#     </tr>
#     <tr>
#       <th id="T_86bcc_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_86bcc_row7_col0" class="data row7 col0" >Skl GBM</td>
#       <td id="T_86bcc_row7_col1" class="data row7 col1" >24.644041</td>
#       <td id="T_86bcc_row7_col2" class="data row7 col2" >4.960085</td>
#       <td id="T_86bcc_row7_col3" class="data row7 col3" >0.246440</td>
#       <td id="T_86bcc_row7_col4" class="data row7 col4" >49.060587</td>
#     </tr>
#     <tr>
#       <th id="T_86bcc_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_86bcc_row8_col0" class="data row8 col0" >AdaBoost</td>
#       <td id="T_86bcc_row8_col1" class="data row8 col1" >31.429160</td>
#       <td id="T_86bcc_row8_col2" class="data row8 col2" >5.593184</td>
#       <td id="T_86bcc_row8_col3" class="data row8 col3" >0.314292</td>
#       <td id="T_86bcc_row8_col4" class="data row8 col4" >40.938832</td>
#     </tr>
#     <tr>
#       <th id="T_86bcc_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_86bcc_row9_col0" class="data row9 col0" >svr</td>
#       <td id="T_86bcc_row9_col1" class="data row9 col1" >49.246617</td>
#       <td id="T_86bcc_row9_col2" class="data row9 col2" >6.772513</td>
#       <td id="T_86bcc_row9_col3" class="data row9 col3" >0.492466</td>
#       <td id="T_86bcc_row9_col4" class="data row9 col4" >11.986024</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model = regressors[results_ord.iloc[0][0]]
best_model

# %%
best_model.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# _catboost.pyx in _catboost.get_float_feature()
#
# _catboost.pyx in _catboost._FloatOrNan()
#
# _catboost.pyx in _catboost._FloatOrNanFromString()
#
# TypeError: Cannot convert 'b'1991-08-07 12:20:00'' to float
#
# During handling of the above exception, another exception occurred:
#
# CatBoostError                             Traceback (most recent call last)
# C:\Users\VARUNK~1\AppData\Local\Temp/ipykernel_16336/4167661866.py in <module>
# ----> 1 best_model.fit(x,y)
#
# C:\Anaconda\envs\strive\lib\site-packages\catboost\core.py in fit(self, X, y, cat_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5259                          use_best_model, eval_set, verbose, logging_level, plot, column_description,
#    5260                          verbose_eval, metric_period, silent, early_stopping_rounds,
# -> 5261                          save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5262
#    5263     def predict(self, data, prediction_type=None, ntree_start=0, ntree_end=0, thread_count=-1, verbose=None, task_type="CPU"):
#
# C:\Anaconda\envs\strive\lib\site-packages\catboost\core.py in _fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    1987             silent=silent, early_stopping_rounds=early_stopping_rounds, save_snapshot=save_snapshot,
#    1988             snapshot_file=snapshot_file, snapshot_interval=snapshot_interval, init_model=init_model,
# -> 1989             callbacks=callbacks
#    1990         )
#    1991         params = train_params["params"]
#
# C:\Anaconda\envs\strive\lib\site-packages\catboost\core.py in _prepare_train_params(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks)
#    1867         train_pool = _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs,
#    1868                                        sample_weight, group_id, group_weight, subgroup_id, pairs_weight,
# -> 1869                                        baseline, column_description)
#    1870         if train_pool.is_empty_:
#    1871             raise CatBoostError("X is empty.")
#
# C:\Anaconda\envs\strive\lib\site-packages\catboost\core.py in _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, column_description)
#    1152             raise CatBoostError("y has not initialized in fit(): X is not catboost.Pool object, y must be not None in fit().")
#    1153         train_pool = Pool(X, y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features, pairs=pairs, weight=sample_weight, group_id=group_id,
# -> 1154                           group_weight=group_weight, subgroup_id=subgroup_id, pairs_weight=pairs_weight, baseline=baseline)
#    1155     return train_pool
#    1156
#
# C:\Anaconda\envs\strive\lib\site-packages\catboost\core.py in __init__(self, data, label, cat_features, text_features, embedding_features, column_description, pairs, delimiter, has_header, ignore_csv_quoting, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count, log_cout, log_cerr)
#     617                     )
#     618
# --> 619                 self._init(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#     620         super(Pool, self).__init__()
#     621
#
# C:\Anaconda\envs\strive\lib\site-packages\catboost\core.py in _init(self, data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#    1133             baseline = np.reshape(baseline, (samples_count, -1))
#    1134             self._check_baseline_shape(baseline, samples_count)
# -> 1135         self._init_pool(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#    1136
#    1137
#
# _catboost.pyx in _catboost._PoolBase._init_pool()
#
# _catboost.pyx in _catboost._PoolBase._init_pool()
#
# _catboost.pyx in _catboost._PoolBase._init_features_order_layout_pool()
#
# _catboost.pyx in _catboost._set_features_order_data_pd_data_frame()
#
# _catboost.pyx in _catboost.create_num_factor_data()
#
# _catboost.pyx in _catboost.get_float_feature()
#
# CatBoostError: Bad value for num_feature[non_default_doc_idx=0,feature_idx=0]="1991-08-07 12:20:00": Cannot convert 'b'1991-08-07 12:20:00'' to float

# %%
test_pred = np.ceil(best_model.predict(x_test))

test_pred[0]
# Out:
# 37.0

# %%
sub = pd.DataFrame(test_pred, columns=["congestion"])
sub.head()
# Out:
#    congestion
# 0        37.0
# 1        38.0

# %%
import joblib
model = regressors[f'{results_ord.iloc[0,0]}']
joblib.dump(model, 'model.pkl')
# Out:
# ['model.pkl']

# %%
df_te = pd.read_csv('testing.csv')

# %%
df_te.head()
# Out:
#    row_id                 time  x  y direction  congestion
# 0  599999  1991-08-07 12:20:00  2  1        SW          48
# 1  600000  1991-08-07 12:20:00  2  1        WB          62
# 2  600001  1991-08-07 12:20:00  2  2        EB          58
# 3  600002  1991-08-07 12:20:00  2  2        NB          54
# 4  600003  1991-08-07 12:20:00  2  2        NE          38

# %%
df_te = df_te.drop(['row_id'], axis = 1)

# %%
df_te.head()
# Out:
#                   time  x  y direction  congestion
# 0  1991-08-07 12:20:00  2  1        SW          48
# 1  1991-08-07 12:20:00  2  1        WB          62
# 2  1991-08-07 12:20:00  2  2        EB          58
# 3  1991-08-07 12:20:00  2  2        NB          54
# 4  1991-08-07 12:20:00  2  2        NE          38

# %%
x = df_te.iloc[:,:-1]
y = df_te.iloc[:,-1]

# %%
x.head()
# Out:
#                   time  x  y direction
# 0  1991-08-07 12:20:00  2  1        SW
# 1  1991-08-07 12:20:00  2  1        WB
# 2  1991-08-07 12:20:00  2  2        EB
# 3  1991-08-07 12:20:00  2  2        NB
# 4  1991-08-07 12:20:00  2  2        NE

# %%
y
# Out:
# 0         48
# 1         62
# 2         58
# 3         54
# 4         38
#           ..
# 248831    54
# 248832    28
# 248833    68
# 248834    17
# 248835    24
# Name: congestion, Length: 248836, dtype: int64
